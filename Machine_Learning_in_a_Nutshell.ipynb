# %% [markdown]
# #1. Linear Regression

# %% [markdown]
# + Linear Regression is a supervised ML problem, where we have input & target variable available in data
#
# + Use when target variable is numerical
#
# + There are 3 types of Linear Regression:
#   - Simple - when there is only 1 input & output variable
#   - Multiple - when there are multiple input variables
#   - Polynomial - when data is not linear, we have a parameter "degree of freedom", if we keep it very high: best fit line will try to pass thru all points means overfitting & if we keep it very low, it will ease out & miss critical information in data & underfitting
#
# +  we check if data is linear or not. If its sort of linear then we try to draw a best fit line (y = mx + b) which passes closesly through the data points by finding those values if m & b.
#
# + lets take an example of package as target variable, cpga & iq are input variables
#
# + m denotes the weightage, how much package depends upon cgpa bcoz thats a slope, if slope will be lower then its change will change package lesser then if slope is higher.
#
# + b is offset, so when m * x value will become 0, still package will have some value & thats b
#
# + There are 2 methods to find the best fit line:
#   - closed form technique (using mathematical formula: OLS)
#   - non closed form (Approximation based technique using probabilities etc: Gradient Descent)
#
#
# + when working with lower dimensions we can use OLS & scikit learn linear regression internally uses this technique
#
# + when working with higher dimension, we use Gradient Descent bcoz deriving the value of m & b will be very difficult. In scikit learn there is a class called SGD Regressor which uses gradient descent techqnique

# %% [markdown]
# ## Regression Metrics
# Regression metrics are used to evaluate and measure the performance of predictive models

# %% [markdown]
# - MAE (mean absolute error)
# - MSE (mean squared error)
# - RMSE (root mean squared error)
# - R2 Score
# - Adjusted R2 score

# %% [markdown]
# ### MAE
#
# + calculating the difference b/w actual & predicted & taking a mean of it for all the points is MAE
#
# + goal is to minimize this error
#
# + unit of MAE & Output is similar so it will easy to understand the loss in numbers for example in above data, Package unit is in lpa so 1.5 mae denotes a loss of 1.5lpa
#
# + can handle outliars
#
# + we use modulus when calculating the difference b/w actual & predicted, issue with that is.. its not diffrentiable so cant be optimized

# %% [markdown]
# ###MSE
#
# - In MAE we take modulus, but in mse we take square, thats the only difference
#
# - can be used as loss function bcoz its diffrentiable at all points
#
# - since we are taking square, its unit will also be in square to that of output which make it difficult to interpret
#
# - it penalizes outliars bcoz of "square", so if there are a lot of outliars then we should go with MAE otherwise with less outliars we can go with MSE

# %% [markdown]
# ###RSME
#
# - Its nothing but root of MSE
# - Its unit though is same as of output since we're taking a root
# - all properties remains the same as of MSE

# %% [markdown]
# ***`Above 3 depends on the context, sometime it could be more & sometime it could be less like in case of death prediction any greater then 0 will be more vs when predicting loss we can decide a threshold which could be atleast more then 0, whereas r2 score & adjusted r2 score are independent, It give actual performance in percentage`***

# %% [markdown]
# ### r2 Score
#
# - lets take an example of our data with cgpa & package, in worst case when somebody asks about how much my package could be? you'll calculate the mean & tell them
#
# - but since we have another column, cgpa, so we draw a best fit line, tell them according to cgpa
#
# - In r2 score, we calculate how better best fit performed in comparison to the worst case "mean" technique stated above
#
# - when r2 score is 0, It means SSR/SSM is = 1, It will only be equal to 1 when best fit line is same as mean line meaning regression line is making same mistakes as mean line which means its not able to take any beefit of cgpa, so it means its worst performing model
#
# - when r2 score is 1, it means SSR/SSM is = 0, it can only be 0 when num is = 0 means best fit line is passing through every data point, its perfect line.
#
# - If r2 score is close to 1 (e.g., 0.95), it suggests that your model is doing an excellent job of capturing and explaining the patterns in the data, and it makes highly accurate predictions.
#
# - If r2 score is close to 0 (e.g., 0.05), it suggests that your model is not explaining much of the variance in the dependent variable, and its predictions are not very accurate.
#
# - r2 score -ve means, SSR/SSM is > 1, means num > den, means best fit line is even worst then mean line
#
# - r2 score is 0.8 or anything +ve means this amount of variance in output is being explained by input columns, rest cant be explained

# %% [markdown]
# ###Adjusted r2 Score
#
# - Problem with r2 score is as no of columns increases, r2 score also increases as they are able to explain the variance more
#
# - sometime r2 score also increases or stay uneffected even if data have irrelevant columns, whereas it should decrease
#
# - when we add irrelevant column like temp, denominator will decrease, in num, n-1 will stay constant & r2 score may remain constant or may decrease a little but in both cases, which means num will also decrease therby it will increase the fraction term & when substracted by 1, it will decrease
#
# - when we add relevant column like cgpa, denominator will decrease surely, r2 score will increase rapidaly but since substracting by 1, it will decrease faster then denominator, whole fraction term will go down, hence when substracting from 1, adjusted r2 score will increase.

# %% [markdown]
# #2. Gradient Descent

# %% [markdown]
# + Gradient Descent is an Optimization algorithm
# + In Linear regression, we try to find a best fit line which makes least error on y axis means a line which pass very close as possible from all the points, to find best fit line, we need value of m & b. There are 2 methods to find m & b:
#
#   - **OLS method**: its computationaly very heavy so not good on large dataset with many columns
#
#   - **GradientDescent**: It find approximatly correct values of m & b but it can be applied on larger dataset also. Initially we'll take random values.. & then by iteratating & updating the vaules of m & b we converge to an approximately correct values of m & b
#
#   - Types of Gradient Descent:
#
#   - In **batch gradient descent**, we first read complete data & then update the values of m & b. Its very slow
#
#   - To avoid above, we can use **Stochastic gradient descent** where values of m & b updates on the basis of rows, Its faster but prone to errors
#
#   - **mini batch gradient descent** is a combination of both above, we define a batch size on rows of 300. so now the values of m & b will be updated after reading 30 rows means it will update only 10 times.
#
#   - In **stochastic gradient descent**, it will update only once & in stochastic gradient descent, it will update 300 times

# %% [markdown]
# #3. Regression Analysis

# %% [markdown]
# + Regression analysis is a statistical method used to understand the relationship between a dependent variable (often denoted as "y") and independent variables (often denoted as "x").
#
# + Iterpretting coefficients of model is called Regression Analysis
#
# + Flow of Regression Analysis
#   - Define the research question, identify input & target variables
#   - Gather data, It must be cleaned & preprocessed to handle missing values, outliars etc
#   - Perform EDA to understand the relationship
#   - Validate assumptions (linear regression has some underlying assumptions including linearity, independence of error, constant variance of error & normality of error. use diagnostic plots & statistical tests to check whether these assumptions hold true for your data)
#   - train model & after training the model, you'll get the values of coefficients of regression model.
#   - interpret the model:analyse the estimated regression coefficients, thier standard errors, p-value & t-value to determine the statistical significance of the relation b/w dependant & independant variable. r-squared & adjusted r-squared values can provide insights into the goodness-of-fit of the model & proportion of variation in dependant variable explained by the independent variable.
#   - After analysis, you validate the model' predictive accuracy
#   - Report the results
#
# + What's the use of Regression Analysis?
#   - Not everyone is mad about prediction, we sometime want to understand the relationship between target & input variables
#
#   - for ex: we've data of ads we ran on tv, internet, yt, fb, linkedin etc & sales
#
#   - we need to find the relation b/w sales on ads ran on tv, internet, yt, fb etc so that we know in future how much to spend on what. which ad converts into more sales

# %% [markdown]
# #4. Feature Selection

# %% [markdown]
# ***Feature selection involves choosing the most relevant and important features (or variables) from your dataset to build a model. The goal is to improve the model's performance by reducing the number of features without losing critical information.***
#
# 1. Filter method: This method involves filtering features based on statistical characteristics.
#    - **removing duplicate features**
#    - **variance threshold method**: If dataset includes features like constant or quassiconstant then use variance threshold method.. In this method we calculate a variance of each feature, decide a threshold & remove features whose variance is less then the threshold value
#    - **corelation**: In this method we first calculate the corelation b/w each feature & target feature, decide a threshold corelation value & remove all features less then threshold value, another approach could be, we'll find corection b/w all columns & see if multi-colinearity exists in the data & remove highly corelated columns
#    - **ANOVA test**: ANOVA (Analysis of Variance) test is a statistical method used for feature selection, It can help identify the most relevant features when the target variable is categorical.
#
#     In hypotheis testing, we come to a conclusion on population dataset based on sample dataset
#
#     We'll divide into Null & Alternate Hypothesis & collect evidences
#
#     Apply different techniques (ANOVA, Chi-Square, T-test) & find out whether Null hypothesis is true or Alternate hypothesis is True
#
#     If the p-value (significance value) comes out to be less then 0.05 then we'll reject Null hypothesis & accept alternate hypothesis
#
#     when you have 1 categorical feature, apply: 1-sample proportion test
#     when you have 2 categorical feature, apply: chi-square test
#     when 1 numerical feature, apply: T-test
#     when 2 numerical features, apply: co-relation (value ranges -1 to 1), If it comes out to be 0 or close to 0 then we'll reject alternate & accept null hypothesis
#     when categorical with more more then 2 categories & numerical features, apply: ANOVA test
#
#     Null hypothesis is that features are not relevant
#
#    - **Chi-Square Test**: Chi-Square tells the relationship b/w input & output column, where both columns are categorical.
#
#    - **Mutual information**: It evaluates the relationship between a feature and the target variable. It measures how much information about the target variable can be obtained from the feature.
#
# 2. Wrapper method: Filter techniques compare one column at a time to the target, ignoring relationships between multiple columns like latitude and longitude. Wrapper methods fix this by considering these relationships, making the analysis more meaningful.
#
#     Wrapper methods involve creating groups of different features, like f1, f2, f3... and the target (let's call it 'y'). For instance, if we have f1, f2, f3, f4, and y, we'd make subsets like (f1, f2, y), (f2, f3, y), (f3, f4, y), and so on.
#
#     Then, we use a machine learning algorithm on these subsets to measure their performance. This helps us find which combination of features gives the best result in terms of accuracy or how well it predicts the outcome. The combination that works best will be the most important features
#
#     subsets can contain any number of input features together. They're not limited to just two features; they can include multiple features combined with the target variable. These subsets can consist of various combinations, including two features, three features, or more, depending on what works best for the analysis.
#
#     ![image.png](data:image/png;base64,...)
#
#     - **Exhaustive feature selection** is a method where you try out every possible combination of features (or variables) to figure out which combination gives the best performance for a particular machine learning model. It involves evaluating all possible subsets of features to find the one that optimizes the model's performance based on certain criteria, such as accuracy or predictive power. However, this method can be computationally intensive and may not be practical for datasets with a large number of features.
#
#     - **Sequential forward selection** Lets say we have 4 features. At first we'll build a model without taking any input feature so it'll be predicting on the basis of mean, then we'll build model for each, find accuracy & select the feature with best acuracy --> f1
#
#     then we'll build models using the selected column with the rest of the columns in combination --> f1,f3
#
#     then we do the same proces again.. f1,f4,f3
#
#     then we do the same process again.. and we found that accuracy for f1,f3,f4 is highest
#
#     Its called forward selection bcoz we keep adding 1-1 feature
#
#     we're building the same no of models as in backward elimination:
#
#     - **Backward elimination** involves selecting all features unlike forword selection & then removing 1-1 feature 1 by 1 and train ml model & selecting the combination with highet accuracy.
#
#     - **Recursive Feature Elimination (RFE)** Lets say we have 4 features & we have to perform feature selection & find the best festures using RFE,we use a model which has coeff_ or feature_importance_attribute. we'll remove columns with lowest feature_importance, repeat the same process again & again & we'll get the most important feature at the end.
#
# 3. **Embeded method**
#      It solves the drawbacks of "feature interaction" in Filter method & "computational complexity" in Wrapper method
#
#     In embeded method, feature selection becomes the part of model building.
#
#     At the time of model training, it also calculates "feature importance"
#
#     Its computationaly efficient then wrapper methods
#
#     Any ml algorithm which has co-efficient & feature_importance_ attributes available, can be used for this operation
#
#     Any machine learning algorithm that provides access to coefficients or feature importance attributes can be used effectively for feature selection within embedded methods.
#
#     Here's why these attributes matter:
#
#     Algorithms like linear regression, logistic regression, and support vector machines provide coefficients. These coefficients indicate the weight or importance assigned to each feature in the model. Feature Importance:
#
#     Other algorithms such as decision trees, random forests, gradient boosting machines, and certain ensemble methods offer a feature importance score. This score signifies how much each feature contributes to the model's predictive ability.
#
#     In embedded methods, these attributes—whether coefficients or feature importance scores—are utilized to identify and select the most influential features for the model. By analyzing these attributes, the method automatically discerns which features are more impactful or contribute significantly to predicting the target variable.
#
# 4. Hybrid method

# %% [markdown]
# #5. Regularization

# %% [markdown]
# + Every ML model can have 2 type of errors
#   1. Reducible errors
#   2. Irreducible erros
#
# + **Irrudicible errors** are those which can't be removed from data, they are naturally present in data like in age, cgpa & lpa dataset there are changes some higher cgpa students got less lpa & vice versa which is exception & it can't be removed
#
# + **Reducible errors**: Since we can't have complete data, so the models we create are based on sample data(y' = mx + b) whereas actual ml model could be (y = mx + b). difference b/w (y - y') is reducible error
#
# + Reducible error encompasses both Bias & Variance
#
# + **Bias & Variance tradeoff**: ML model could be performing good on training but worst on test are high variance & called overfitting whereas models performing worst on training are high bias & called underfitting.
#
# + The real challenge lies in finding the sweet spot between these two extremes. When you try to reduce bias, the model might start capturing more complexities and details, inadvertently increasing variance. Similarly, if you focus on reducing variance, the model might become too generalized, potentially increasing bias.
#
# + Ther will always be a trade-off b/w bias & variance in any ml  model. Bias can be fixed using complex models & Variance can be fixed using regularization.
#
# + As a datascientist, our goal is to find a balance b/w both bias & variance where they are at thier lowest.
#
# ![image.png](data:image/png;base64,...)
#
#
# + Regularization is a technique used to reduce overfitting in complex models means reducing high variance, means we have to reduce the slope m
#
# + There are 3 techniques:
#   - **Ridge(L2)**: When you know that all columns are important
#   - **Lasso(L1)**: When you know few columns might not be important becuase it can act as "Feature Selection" technique removing unimportant columns
#   - **ElasticNet**: Its a combination of both, Where you don't know which regularization technique to select
#
#
# + In Ridge, coefficients move towards 0 but never become 0 whereas Lasso creates sparsity (means some coefficients turn 0) bcoz of "lambda" or "alpha" hyper-parameter which is in denominator in ridge so no matter how much you increase the value of alpha it will never reach 0, it become very close to 0 & alpha is in numerator in lasso which drives coefficinets value to 0
#
# + Higher coefficinets decrease faster bcoz the main goal of reducing overfitting is to reduce variance means reduce slope
